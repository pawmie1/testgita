# %% [markdown]
# <a href="https://colab.research.google.com/github/pawmie1/testgita/blob/master/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   Element listy
# 2.   Element listy

# %%
print('Hallo colab')
# Out:
# Hallo colab
